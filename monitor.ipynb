# %%
from utils import plot_memory_usage2
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Memory leak analysis

# %%
def plot_memory_usage2(results_csv_filepath:str):
    """Plot memory usage per epoch to help spot memory leaks"""
    df = pd.read_csv(results_csv_filepath)
    x = df.index.values
    y = [df['memalloc_Gb']]
    plt.stackplot(x, y, labels=['memcache_Gb', 'memalloc_Gb'])
    #plt.legend(loc='upper left')
    plt.xlabel('epoch')
    plt.ylabel('Gb')
    plt.title('Updated at: ' + str(datetime.now()))
    plt.show()
    return

# %%
def plot_memory_usage3(results_csv_filepath:str):
    """Plot memory usage per epoch to help spot memory leaks"""
    df = pd.read_csv(results_csv_filepath)
    df = df[:1500]
    x = df.index.values
    y = [df['memalloc_Gb']]
    plt.stackplot(x, y, labels=['memalloc_Gb', 'memcache_Gb'])
    #plt.legend(loc='upper left')
    plt.xlabel('iter')
    plt.ylabel('Gb')
    plt.title('Updated at: ' + str(datetime.now()))
    plt.show()
    return

plt.figure(figsize=(15, 5))
plot_memory_usage3('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %% [markdown]
# ## Fixed memory leak

# %%
plt.figure(figsize=(10, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/awd_lstm_fixed_seq_len.csv')

# %% [markdown]
# The model is now holding a constant amount of memory during training.

# %% [markdown]
# #### Epoch training time is increasing linearly :(

# %%
df = pd.read_csv('./results/awd_lstm_fixed_seq_len.csv')
sns.lineplot(x='epoch', y='time', data=df);

# %% [markdown]
# #### Validation perplexity during training

# %%
df = pd.read_csv('./results/awd_lstm_fixed_seq_len.csv')
sns.lineplot(x='epoch', y='val_ppl', data=df);

# %% [markdown]
# ## Experiment 1

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/awd_lstm_fixed_seq_len_1.csv')

# %% [markdown]
# ## Experiment 2

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/awd_lstm_fixed_seq_len_2.csv')

# %% [markdown]
# ## Experiment 3

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/awd_lstm_fixed_seq_len_3.csv')

# %%
df = pd.read_csv('./results/awd_lstm_fixed_seq_len_3.csv')
sns.lineplot(x='epoch', y='time', data=df);

# %%
df = pd.read_csv('./results/batch_metrics.csv')
sns.lineplot(x=df.index.values, y=df['batch_time']);
