# %%
from utils import plot_memory_usage2
import matplotlib.pyplot as plt

# %%
def plot_memory_usage2(results_csv_filepath:str):
    """Plot memory usage per epoch to help spot memory leaks"""
    df = pd.read_csv(results_csv_filepath)
    x = df.index.values
    y = [df['memalloc_Gb']]
    plt.stackplot(x, y, labels=['memcache_Gb', 'memalloc_Gb'])
    #plt.legend(loc='upper left')
    plt.xlabel('epoch')
    plt.ylabel('Gb')
    plt.title('Updated at: ' + str(datetime.now()))
    plt.show()
    return

plt.figure(figsize=(15, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(5, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plt.figure(figsize=(7, 5))
plot_memory_usage2('./results/batch_metrics.csv')

# %%
plot_memory_usage2('./results/awd_lstm_fixed_seq_len.csv')

# %%
import torch
import gc

for obj in gc.get_objects():
    try:
        if torch.is_tensor(obj) or (hasattr(obj, 'data') and torch.is_tensor(obj.data)):
            print(type(obj), obj.size())
    except:
        pass
# Out:
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/distributed/distributed_c10d.py:86: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn("torch.distributed.reduce_op is deprecated, please use "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/distributed/distributed_c10d.py:86: UserWarning: torch.distributed.reduce_op is deprecated, please use torch.distributed.ReduceOp instead
#   warnings.warn("torch.distributed.reduce_op is deprecated, please use "
# /home/paperspace/anaconda3/envs/fastai/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: Index.data is deprecated and will be removed in a future version
#   import sys

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

def plot_memory_usage3(results_csv_filepath:str):
    """Plot memory usage per epoch to help spot memory leaks"""
    df = pd.read_csv(results_csv_filepath)
    df = df[:1500]
    x = df.index.values
    y = [df['memalloc_Gb']]
    plt.stackplot(x, y, labels=['memalloc_Gb', 'memcache_Gb'])
    #plt.legend(loc='upper left')
    plt.xlabel('iter')
    plt.ylabel('Gb')
    plt.title('Updated at: ' + str(datetime.now()))
    plt.show()
    return

plt.figure(figsize=(15, 5))
plot_memory_usage3('./results/batch_metrics.csv')
